# %%
import json

from utils import *

with open('data.txt', 'r') as f:
    parts = json.load(f)

# %%
parts
# Out:
# [{'Body': {'material': 'Волоконный композит',
#    'name': 'AgDrone',
#    'portability': True,
#    'price': 15000,
#    'weight': 180}},
#  {'Body': {'material': 'Экструдированный пенополистирол',
#    'name': 'Hubsan_H501S',
#    'portability': True,
#    'price': 10500,
#    'weight': 230}},
#  {'Body': {'material': 'Кевлар',
#    'name': 'Raytheon',
#    'portability': False,
#    'price': 7000,
#    'weight': 300}},
#  {'Body': {'material': 'Углепластика',
#    'name': 'Тахион',
#    'portability': False,
#    'price': 8000,
#    'weight': 450}},
#  {'Engine': {'engine_type': 'Бесколлекторный электродвигатель',
#    'name': 'DJI SPARK',
#    'number': 6,
#    'price': 10000,
#    'propulsion_type': 'Реактивная тяга',
#    'weight': 160}},
#  {'Engine': {'engine_type': 'Коллекторный электродвигатель',
#    'name': 'WL Toys WL-Q282Jw',
#    'number': 4,
#    'price': 8000,
#    'propulsion_type': 'Реактивная тяга',
#    'weight': 200}},
# ...
